# %% [markdown]
# # 한국 주식 데이터를 크롤링합니다.

# %% [markdown]
# ## 예전에 <심이삭>이 만들어 두었던 것을 참조합니다.
# ## 링크: https://github.com/gilgarad/stock_predict/blob/master/src/data_crawler/stock_info.py

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from os.path import join, exists, dirname
from os import makedirs

# %% [markdown]
# # 크롤링 구현 순서:

# %% [markdown]
# # 1. 주가시스템에 있는 회사 리스트 가지고 오기
# ## 설명: 등록된 회사 리스트와 종목 코드를 수집합니다.

# %%
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
# 종목코드가 6자리이기 때문에 6자리를 맞춰주기 위해 설정해줌
code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)
# 우리가 필요한 것은 회사명과 종목코드이기 때문에 필요없는 column들은 제외해준다.
code_df = code_df[['회사명', '종목코드']]  # 한글로된 컬럼명을 영어로 바꿔준다.
company_info = code_df.rename(columns={'회사명': 'name', '종목코드': 'code'})

# %%
company_info
# Out:
#             name    code
# 0          GS글로벌  001250
# 1          HSD엔진  082740
# 2          KG케미칼  001390
# 3          LG이노텍  011070
# 4            OCI  010060
# 5         SK네트웍스  001740
# 6        SK이노베이션  096770
# 7            STX  011810
# 8         WISCOM  024070
# 9        갤럭시아에스엠  011420
# 10        경동도시가스  267290
# 11        경동인베스트  012320
# 12          고려아연  010130
# 13          고려제강  002240
# 14          극동유화  014530
# 15         까뮤이앤씨  013700
# 16          남양유업  003920
# 17         노루페인트  090350
# 18        대림씨엔에스  004440
# 19          대영포장  014160
# 20          대원제약  003220
# 21         대유에이텍  002880
# 22          대한해운  005880
# 23          동남합성  023450
# 24      동아쏘시오홀딩스  000640
# 25            동양  001520
# 26        롯데손해보험  000400
# 27          롯데쇼핑  023530
# 28           마니커  027740
# 29        모두투어리츠  204210
# ...          ...     ...
# 2246         피엔티  137400
# 2247       피제이전자  006140
# 2248        하이로닉  149980
# 2249     하이비젼시스템  126700
# 2250          하츠  066130
# 2251      한국기업평가  034950
# 2252     한국제6호스팩  281410
# 2253         한네트  052600
# 2254       한라IMS  092460
# 2255      한화수성스팩  265920
# 2256      홈센타홀딩스  060560
# 2257         휴맥스  115160
# 2258        관악산업  076340
# 2259          굿센  243870
# 2260       나라소프트  288490
# 2261      네추럴FNP  086220
# 2262        다이노나  086080
# 2263        라온테크  232680
# 2264        럭스피아  092590
# 2265    루켄테크놀러지스  162120
# 2266     메디젠휴먼케어  236340
# 2267     아이케이세미콘  149010
# 2268        알로이스  271400
# 2269       엄지하우스  224810
# 2270       엔케이맥스  262760
# 2271  인프라웨어테크놀러지  247300
# 2272     지앤이헬스케어  299480
# 2273          툴젠  199800
# 2274          틸론  217880
# 2275       판도라티비  202960
#
# [2276 rows x 2 columns]

# %% [markdown]
# # 2. 데이터 수집하기
# ## 내용: 네이버에서 위에서 수집한 종목코드의 주가 데이터를 수집합니다.

# %%
def get_stock_data(company_name, by_year=list(), recent_n_data=list()):
    t = datetime.now()
    print('Crawling Company Name:', company_name)
    
    # 1. 회사 종목코드와 데이터를 수집하기 위한 대상 url을 생성합닏.
    code = company_info.query("name=='{}'".format(company_name))['code'].to_string(index=False)
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    print("요청 URL = {}".format(url))

    # 2. (option) 지정된 year 또는 타겟 날짜로부터 가장 최근 n일의 데이터를 수집하고자 할 때 지정하기 위한 로직입니다.
    yrs = ""
    min_year = -1
    target_date = -1
    num_seq = -1

    if len(recent_n_data) == 2:
        target_date = str(recent_n_data[0])
        target_date = target_date[:4] + '.' + target_date[4:6] + '.' + target_date[6:8]  # yyyy.mm.dd
        num_seq = recent_n_data[1]

    if len(by_year) != 0 and target_date == -1:
        yrs = "|".join(str(yr) for yr in by_year)
        min_year = sorted(by_year)[0]
        print('Collecting years... ', by_year)
        # print('Mininum Year: %i' % min_year)

    # 3. UI에 Display된 페이지 데이터를 수집하기 때문에 max page를 정해놓고 시도합니다.
    max_page = 1000
    df = pd.DataFrame()

    for page in range(1, max_page):
        pg_url = '{url}&page={page}'.format(url=url, page=page)
        d = pd.read_html(pg_url, header=0)[0]
        d = d.dropna()

        # 3-1. 마지막 페이지 수집시, 이전 페이지의 중복된 날짜도 함께 수집되었는지 확인하고 프로세스를 멈춥니다.
        if df.shape[0] != 0 and d['날짜'][1] in df['날짜'].tolist():
            # Max page reached
            print('Break page:', page)
            break

        # 3-2. 타겟 날짜에 대한 데이터만 수집할 때에만 해당됩니다.
        if target_date != -1:
            if df.shape[0] == 0:
                d = d[d['날짜'].str.contains(target_date)]
                if d.shape[0] == 0:
                    continue

            df = df.append(d)

            if df.shape[0] >= num_seq:
                df = df.head(num_seq)
                break

        # 3-3. 타겟 year만 수집할 때에만 해당됩니다. 타겟 year 이전 해의 데이터가 수집되었다면 프로세스를 멈춥니다.
        if min_year != -1 and target_date == -1 and min_year > int(d['날짜'][d.shape[0] - 1][:4]):
            print('Found minimum year, break page:', page)
            break

        df = df.append(d, ignore_index=True)

    # 4. 수집된 데이터를 가볍게 가공합니다.
    df['name'] = pd.Series([company_name] * len(df['날짜']), index=df.index)
    df = df.rename(columns={'날짜': 'date', '종가': 'final_price', '전일비': 'compare_to_prior', '시가': 'start_price',
                            '고가': 'highest_price', '저가': 'lowest_price', '거래량': 'num_of_traded'})

    # 5. 수집된 데이터 중 타겟 year에 해당하는 데이터만 재정리 합니다.
    if min_year != -1:
        df = df[df['date'].str.contains(yrs)]

    t = datetime.now() - t
    print('Elapsed time:', t)

    return df

# %%
all_data = pd.DataFrame()
collect_start_time = datetime.now()
for idx, company_name in enumerate(company_info['name']):
    print('[%i]' %idx)
    stock_data = get_stock_data(company_name=company_name)
    all_data = pd.concat([all_data, stock_data])
print('Crawling data finished. Total elapsed time:', datetime.now() - collect_start_time)
# Out:
# [0]
# Crawling Company Name: GS글로벌
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001250
# Break page: 577
# Elapsed time: 0:00:59.333009
# [1]
# Crawling Company Name: HSD엔진
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=082740
# Break page: 207
# Elapsed time: 0:00:15.257557
# [2]
# Crawling Company Name: KG케미칼
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001390
# Break page: 577
# Elapsed time: 0:00:48.882805
# [3]
# Crawling Company Name: LG이노텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011070
# Break page: 269
# Elapsed time: 0:00:26.519974
# [4]
# Crawling Company Name: OCI
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=010060
# Break page: 577
# Elapsed time: 0:00:57.889990
# [5]
# Crawling Company Name: SK네트웍스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001740
# Break page: 577
# Elapsed time: 0:00:55.899363
# [6]
# Crawling Company Name: SK이노베이션
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=096770
# Break page: 293
# Elapsed time: 0:00:23.968411
# [7]
# Crawling Company Name: STX
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011810
# Break page: 574
# Elapsed time: 0:01:13.561174
# [8]
# Crawling Company Name: WISCOM
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=024070
# Break page: 459
# Elapsed time: 0:00:58.631348
# [9]
# Crawling Company Name: 갤럭시아에스엠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011420
# Break page: 574
# Elapsed time: 0:00:59.954749
# [10]
# Crawling Company Name: 경동도시가스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=267290
# Break page: 50
# Elapsed time: 0:00:03.664775
# [11]
# Crawling Company Name: 경동인베스트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=012320
# Break page: 554
# Elapsed time: 0:01:23.955133
# [12]
# Crawling Company Name: 고려아연
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=010130
# Break page: 574
# Elapsed time: 0:01:04.517843
# [13]
# Crawling Company Name: 고려제강
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002240
# Break page: 577
# Elapsed time: 0:00:56.087124
# [14]
# Crawling Company Name: 극동유화
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=014530
# Break page: 574
# Elapsed time: 0:00:50.221307
# [15]
# Crawling Company Name: 까뮤이앤씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=013700
# Break page: 574
# Elapsed time: 0:01:12.480373
# [16]
# Crawling Company Name: 남양유업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003920
# Break page: 577
# Elapsed time: 0:01:01.969949
# [17]
# Crawling Company Name: 노루페인트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=090350
# Break page: 319
# Elapsed time: 0:00:26.457174
# [18]
# Crawling Company Name: 대림씨엔에스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=004440
# Break page: 78
# Elapsed time: 0:00:12.300602
# [19]
# Crawling Company Name: 대영포장
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=014160
# Break page: 574
# Elapsed time: 0:00:52.146177
# [20]
# Crawling Company Name: 대원제약
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003220
# Break page: 519
# Elapsed time: 0:01:07.732216
# [21]
# Crawling Company Name: 대유에이텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002880
# Break page: 577
# Elapsed time: 0:01:31.304834
# [22]
# Crawling Company Name: 대한해운
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005880
# Break page: 577
# Elapsed time: 0:01:35.806230
# [23]
# Crawling Company Name: 동남합성
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023450
# Break page: 560
# Elapsed time: 0:01:06.537224
# [24]
# Crawling Company Name: 동아쏘시오홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000640
# Break page: 577
# Elapsed time: 0:01:11.163442
# [25]
# Crawling Company Name: 동양
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001520
# Break page: 577
# Elapsed time: 0:01:08.297792
# [26]
# Crawling Company Name: 롯데손해보험
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000400
# Break page: 577
# Elapsed time: 0:01:22.015996
# [27]
# Crawling Company Name: 롯데쇼핑
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023530
# Break page: 329
# Elapsed time: 0:00:42.989384
# [28]
# Crawling Company Name: 마니커
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=027740
# Break page: 456
# Elapsed time: 0:01:10.100061
# [29]
# Crawling Company Name: 모두투어리츠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=204210
# Break page: 66
# Elapsed time: 0:00:08.388549
# [30]
# Crawling Company Name: 무림페이퍼
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=009200
# Break page: 577
# Elapsed time: 0:01:19.443239
# [31]
# Crawling Company Name: 부국증권
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001270
# Break page: 577
# Elapsed time: 0:01:24.275427
# [32]
# Crawling Company Name: 삼성SDI
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=006400
# Break page: 577
# Elapsed time: 0:01:30.627036
# [33]
# Crawling Company Name: 삼성바이오로직스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=207940
# Break page: 63
# Elapsed time: 0:00:07.271022
# [34]
# Crawling Company Name: 삼성출판사
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=068290
# Break page: 416
# Elapsed time: 0:00:58.515100
# [35]
# Crawling Company Name: 삼성카드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=029780
# Break page: 295
# Elapsed time: 0:00:45.372119
# [36]
# Crawling Company Name: 삼성화재해상보험
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000810
# Break page: 577
# Elapsed time: 0:01:19.394381
# [37]
# Crawling Company Name: 삼양홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000070
# Break page: 576
# Elapsed time: 0:01:30.146174
# [38]
# Crawling Company Name: 삼영전자공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005680
# Break page: 577
# Elapsed time: 0:01:22.464241
# [39]
# Crawling Company Name: 삼영화학공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003720
# Break page: 577
# Elapsed time: 0:01:15.039709
# [40]
# Crawling Company Name: 상상인증권
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001290
# Break page: 577
# Elapsed time: 0:03:12.367345
# [41]
# Crawling Company Name: 선도전기
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007610
# Break page: 577
# Elapsed time: 0:01:19.808584
# [42]
# Crawling Company Name: 선진
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=136490
# Break page: 204
# Elapsed time: 0:00:21.974632
# [43]
# Crawling Company Name: 세원셀론텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=091090
# Break page: 317
# Elapsed time: 0:01:04.481754
# [44]
# Crawling Company Name: 신송홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=006880
# Break page: 136
# Elapsed time: 0:00:22.085699
# [45]
# Crawling Company Name: 신풍제약
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=019170
# Break page: 574
# Elapsed time: 0:01:39.151524
# [46]
# Crawling Company Name: 신한알파리츠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=293940
# Break page: 20
# Elapsed time: 0:00:07.467853
# [47]
# Crawling Company Name: 신한지주
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=055550
# Break page: 438
# Elapsed time: 0:01:00.993591
# [48]
# Crawling Company Name: 에넥스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011090
# Break page: 574
# Elapsed time: 0:01:45.579161
# [49]
# Crawling Company Name: 영화금속
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=012280
# Break page: 574
# Elapsed time: 0:02:10.355869
# [50]
# Crawling Company Name: 우진
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=105840
# Break page: 218
# Elapsed time: 0:00:39.979165
# [51]
# Crawling Company Name: 원림
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005820
# Break page: 577
# Elapsed time: 0:01:28.836056
# [52]
# Crawling Company Name: 윌비스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008600
# Break page: 577
# Elapsed time: 0:01:23.416980
# [53]
# Crawling Company Name: 유나이티드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=033270
# Break page: 480
# Elapsed time: 0:01:36.995896
# [54]
# Crawling Company Name: 유니온머티리얼
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=047400
# Break page: 239
# Elapsed time: 0:00:35.787824
# [55]
# Crawling Company Name: 이리츠코크렙
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=088260
# Break page: 23
# Elapsed time: 0:00:02.200398
# [56]
# Crawling Company Name: 인지컨트롤스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023800
# Break page: 459
# Elapsed time: 0:01:00.406429
# [57]
# Crawling Company Name: 일동제약
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=249420
# Break page: 67
# Elapsed time: 0:00:07.008079
# [58]
# Crawling Company Name: 제이에스코퍼레이션
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=194370
# Break page: 81
# Elapsed time: 0:00:09.137375
# [59]
# Crawling Company Name: 제일약품
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=271980
# Break page: 46
# Elapsed time: 0:00:04.971345
# [60]
# Crawling Company Name: 제일연마
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001560
# Break page: 333
# Elapsed time: 0:00:40.974248
# [61]
# Crawling Company Name: 제일파마홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002620
# Break page: 577
# Elapsed time: 0:01:21.674658
# [62]
# Crawling Company Name: 제주항공
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=089590
# Break page: 87
# Elapsed time: 0:00:10.835987
# [63]
# Crawling Company Name: 조일알미늄
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=018470
# Break page: 574
# Elapsed time: 0:01:13.492238
# [64]
# Crawling Company Name: 조흥
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002600
# Break page: 577
# Elapsed time: 0:01:17.347570
# [65]
# Crawling Company Name: 종근당홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001630
# Break page: 577
# Elapsed time: 0:01:11.256123
# [66]
# Crawling Company Name: 지역난방공사
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=071320
# Break page: 230
# Elapsed time: 0:00:32.290300
# [67]
# Crawling Company Name: 진도
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=088790
# Break page: 326
# Elapsed time: 0:00:48.681016
# [68]
# Crawling Company Name: 코리아써키트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007810
# Break page: 577
# Elapsed time: 0:01:42.820285
# [69]
# Crawling Company Name: 코스맥스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=192820
# Break page: 126
# Elapsed time: 0:00:19.684312
# [70]
# Crawling Company Name: 코오롱인더
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=120110
# Break page: 230
# Elapsed time: 0:00:46.453308
# [71]
# Crawling Company Name: 코오롱플라스틱
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=138490
# Break page: 196
# Elapsed time: 0:00:23.155453
# [72]
# Crawling Company Name: 키다리스튜디오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=020120
# Break page: 574
# Elapsed time: 0:01:15.308677
# [73]
# Crawling Company Name: 태광산업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003240
# Break page: 577
# Elapsed time: 0:01:21.912511
# [74]
# Crawling Company Name: 태양금속공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=004100
# Break page: 577
# Elapsed time: 0:01:20.786324
# [75]
# Crawling Company Name: 하나투어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=039130
# Break page: 457
# Elapsed time: 0:00:54.623354
# [76]
# Crawling Company Name: 한국가스공사
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036460
# Break page: 477
# Elapsed time: 0:01:07.099350
# [77]
# Crawling Company Name: 한국전자홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=006200
# Break page: 577
# Elapsed time: 0:01:16.960368
# [78]
# Crawling Company Name: 한국제지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002300
# Break page: 577
# Elapsed time: 0:01:13.798735
# [79]
# Crawling Company Name: 한국종합기술
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023350
# Break page: 199
# Elapsed time: 0:00:21.238992
# [80]
# Crawling Company Name: 한국주철관공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000970
# Break page: 577
# Elapsed time: 0:01:16.412323
# [81]
# Crawling Company Name: 한국철강
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=104700
# Break page: 264
# Elapsed time: 0:00:35.943138
# [82]
# Crawling Company Name: 한국패러랠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=168490
# Break page: 150
# Elapsed time: 0:00:17.701347
# [83]
# Crawling Company Name: 한라홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=060980
# Break page: 223
# Elapsed time: 0:00:26.731614
# [84]
# Crawling Company Name: 한미약품
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=128940
# Break page: 218
# Elapsed time: 0:00:30.163099
# [85]
# Crawling Company Name: 한세실업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=105630
# Break page: 252
# Elapsed time: 0:00:35.011155
# [86]
# Crawling Company Name: 한솔로지스틱스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=009180
# Break page: 577
# Elapsed time: 0:01:15.768198
# [87]
# Crawling Company Name: 한일시멘트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=300720
# Break page: 20
# Elapsed time: 0:00:01.737920
# [88]
# Crawling Company Name: 한일철강
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002220
# Break page: 577
# Elapsed time: 0:01:14.024343
# [89]
# Crawling Company Name: 한진
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002320
# Break page: 577
# Elapsed time: 0:01:13.763710
# [90]
# Crawling Company Name: 한창제지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=009460
# Break page: 577
# Elapsed time: 0:01:29.581509
# [91]
# Crawling Company Name: 한화갤러리아타임월드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=027390
# Break page: 459
# Elapsed time: 0:01:11.147406
# [92]
# Crawling Company Name: 현대건설
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000720
# Break page: 577
# Elapsed time: 0:01:08.447183
# [93]
# Crawling Company Name: 현대건설기계
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=267270
# Break page: 51
# Elapsed time: 0:00:06.251229
# [94]
# Crawling Company Name: 현대모비스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=012330
# Break page: 574
# Elapsed time: 0:01:16.731120
# [95]
# Crawling Company Name: 현대비앤지스틸
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=004560
# Break page: 577
# Elapsed time: 0:01:12.917266
# [96]
# Crawling Company Name: 현대홈쇼핑
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=057050
# Break page: 215
# Elapsed time: 0:00:26.723704
# [97]
# Crawling Company Name: 호전실업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=111110
# Break page: 57
# Elapsed time: 0:00:23.487005
# [98]
# Crawling Company Name: 호텔신라
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008770
# Break page: 577
# Elapsed time: 0:01:11.359259
# [99]
# Crawling Company Name: 효성중공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=298040
# Break page: 22
# Elapsed time: 0:00:02.786883
# [100]
# Crawling Company Name: CJ프레시웨이
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=051500
# Break page: 441
# Elapsed time: 0:00:58.439520
# [101]
# Crawling Company Name: CSA 코스믹
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=083660
# Break page: 318
# Elapsed time: 0:00:36.269944
# [102]
# Crawling Company Name: GH신소재
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=130500
# Break page: 143
# Elapsed time: 0:00:21.154768
# [103]
# Crawling Company Name: GST
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=083450
# Break page: 330
# Elapsed time: 0:00:48.570122
# [104]
# Crawling Company Name: KB오토시스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=024120
# Break page: 519
# Elapsed time: 0:01:07.728061
# [105]
# Crawling Company Name: KJ프리텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=083470
# Break page: 265
# Elapsed time: 0:00:31.290357
# [106]
# Crawling Company Name: NHN한국사이버결제
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=060250
# Break page: 429
# Elapsed time: 0:00:52.425825
# [107]
# Crawling Company Name: TJ미디어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=032540
# Break page: 519
# Elapsed time: 0:01:10.473972
# [108]
# Crawling Company Name: YW
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=051390
# Break page: 433
# Elapsed time: 0:00:52.456473
# [109]
# Crawling Company Name: 갤럭시아컴즈
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=094480
# Break page: 293
# Elapsed time: 0:00:33.951291
# [110]
# Crawling Company Name: 교보8호스팩
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=307280
# Break page: 12
# Elapsed time: 0:00:01.188896
# [111]
# Crawling Company Name: 나스미디어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=089600
# Break page: 144
# Elapsed time: 0:00:16.482917
# [112]
# Crawling Company Name: 네오티스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=085910
# Break page: 289
# Elapsed time: 0:00:35.922602
# [113]
# Crawling Company Name: 녹십자셀
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=031390
# Break page: 508
# Elapsed time: 0:01:06.151209
# [114]
# Crawling Company Name: 녹십자엠에스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=142280
# Break page: 109
# Elapsed time: 0:00:12.222860
# [115]
# Crawling Company Name: 뉴인텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=012340
# Break page: 519
# Elapsed time: 0:01:12.375696
# [116]
# Crawling Company Name: 뉴프렉스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=085670
# Break page: 331
# Elapsed time: 0:00:49.244193
# [117]
# Crawling Company Name: 대동기어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008830
# Break page: 519
# Elapsed time: 0:01:12.591507
# [118]
# Crawling Company Name: 대봉엘에스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=078140
# Break page: 332
# Elapsed time: 0:00:39.700730
# [119]
# Crawling Company Name: 대유위니아
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=071460
# Break page: 71
# Elapsed time: 0:00:07.913114
# [120]
# Crawling Company Name: 대한광통신
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=010170
# Break page: 519
# Elapsed time: 0:01:11.778326
# [121]
# Crawling Company Name: 대한뉴팜
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=054670
# Break page: 427
# Elapsed time: 0:00:58.673658
# [122]
# Crawling Company Name: 대한약품
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023910
# Break page: 519
# Elapsed time: 0:01:07.739421
# [123]
# Crawling Company Name: 덕산네오룩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=213420
# Break page: 106
# Elapsed time: 0:00:17.943157
# [124]
# Crawling Company Name: 덱스터
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=206560
# Break page: 84
# Elapsed time: 0:00:09.976260
# [125]
# Crawling Company Name: 디에이피
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=066900
# Break page: 373
# Elapsed time: 0:00:44.710469
# [126]
# Crawling Company Name: 디엔에프
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=092070
# Break page: 285
# Elapsed time: 0:00:39.207767
# [127]
# Crawling Company Name: 디오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=039840
# Break page: 467
# Elapsed time: 0:01:01.178113
# [128]
# Crawling Company Name: 디지틀조선
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=033130
# Break page: 519
# Elapsed time: 0:01:15.011423
# [129]
# Crawling Company Name: 디케이앤디
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=263020
# Break page: 13
# Elapsed time: 0:00:01.495571
# [130]
# Crawling Company Name: 디케이티
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=290550
# Break page: 11
# Elapsed time: 0:00:01.353647
# [131]
# Crawling Company Name: 레드캡투어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=038390
# Break page: 474
# Elapsed time: 0:01:07.196980
# [132]
# Crawling Company Name: 리더스코스메틱
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=016100
# Break page: 405
# Elapsed time: 0:00:59.731131
# [133]
# Crawling Company Name: 마크로젠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=038290
# Break page: 473
# Elapsed time: 0:01:03.915867
# [134]
# Crawling Company Name: 매일홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005990
# Break page: 492
# Elapsed time: 0:00:59.572263
# [135]
# Crawling Company Name: 매직마이크로
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=127160
# Break page: 133
# Elapsed time: 0:00:15.203083
# [136]
# Crawling Company Name: 명성티엔에스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=257370
# Break page: 17
# Elapsed time: 0:00:01.927773
# [137]
# Crawling Company Name: 모비스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=250060
# Break page: 67
# Elapsed time: 0:00:08.224461
# [138]
# Crawling Company Name: 미래컴퍼니
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=049950
# Break page: 357
# Elapsed time: 0:00:40.947793
# [139]
# Crawling Company Name: 미래테크놀로지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=213090
# Break page: 86
# Elapsed time: 0:00:08.373035
# [140]
# Crawling Company Name: 바디텍메드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=206640
# Break page: 109
# Elapsed time: 0:00:12.666226
# [141]
# Crawling Company Name: 부스타
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008470
# Break page: 204
# Elapsed time: 0:00:34.116940
# [142]
# Crawling Company Name: 비츠로시스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=054220
# Break page: 430
# Elapsed time: 0:00:56.389072
# [143]
# Crawling Company Name: 삼기오토모티브
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=122350
# Break page: 227
# Elapsed time: 0:00:26.757881
# [144]
# Crawling Company Name: 삼보판지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=023600
# Break page: 519
# Elapsed time: 0:01:05.280454
# [145]
# Crawling Company Name: 삼본전자
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=111870
# Break page: 211
# Elapsed time: 0:00:24.595563
# [146]
# Crawling Company Name: 삼아제약
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=009300
# Break page: 466
# Elapsed time: 0:01:07.471166
# [147]
# Crawling Company Name: 상상인인더스트리
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=101000
# Break page: 236
# Elapsed time: 0:00:26.078441
# [148]
# Crawling Company Name: 성창오토텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=080470
# Break page: 311
# Elapsed time: 0:00:36.619910
# [149]
# Crawling Company Name: 세미콘라이트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=214310
# Break page: 97
# Elapsed time: 0:00:16.087211
# [150]
# Crawling Company Name: 세보엠이씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011560
# Break page: 519
# Elapsed time: 0:01:06.710502
# [151]
# Crawling Company Name: 세종메디칼
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=258830
# Break page: 25
# Elapsed time: 0:00:02.806310
# [152]
# Crawling Company Name: 셀리드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=299660
# Break page: 7
# Elapsed time: 0:00:00.714984
# [153]
# Crawling Company Name: 셀바스헬스케어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=208370
# Break page: 109
# Elapsed time: 0:00:11.989957
# [154]
# Crawling Company Name: 스튜디오썸머
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008800
# Break page: 519
# Elapsed time: 0:01:19.767499
# [155]
# Crawling Company Name: 승일
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=049830
# Break page: 453
# Elapsed time: 0:00:53.921786
# [156]
# Crawling Company Name: 싸이토젠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=217330
# Break page: 13
# Elapsed time: 0:00:01.480900
# [157]
# Crawling Company Name: 썸에이지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=208640
# Break page: 109
# Elapsed time: 0:00:19.221494
# [158]
# Crawling Company Name: 쎄미시스코
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=136510
# Break page: 185
# Elapsed time: 0:01:00.594095
# [159]
# Crawling Company Name: 씨티젠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036170
# Break page: 477
# Elapsed time: 0:01:07.780246
# [160]
# Crawling Company Name: 아이씨디
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=040910
# Break page: 193
# Elapsed time: 0:00:27.341068
# [161]
# Crawling Company Name: 아이즈비전
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=031310
# Break page: 518
# Elapsed time: 0:01:08.868996
# [162]
# Crawling Company Name: 아이텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=119830
# Break page: 212
# Elapsed time: 0:00:30.278518
# [163]
# Crawling Company Name: 알에프세미
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=096610
# Break page: 285
# Elapsed time: 0:00:46.595741
# [164]
# Crawling Company Name: 알에프텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=061040
# Break page: 421
# Elapsed time: 0:00:56.521760
# [165]
# Crawling Company Name: 알테오젠
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=196170
# Break page: 110
# Elapsed time: 0:00:15.510226
# [166]
# Crawling Company Name: 알티캐스트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=085810
# Break page: 135
# Elapsed time: 0:00:17.063380
# [167]
# Crawling Company Name: 액션스퀘어
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=205500
# Break page: 112
# Elapsed time: 0:00:12.803983
# [168]
# Crawling Company Name: 액트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=131400
# Break page: 208
# Elapsed time: 0:00:47.148020
# [169]
# Crawling Company Name: 에스디시스템
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=121890
# Break page: 219
# Elapsed time: 0:00:34.598965
# [170]
# Crawling Company Name: 에스에프씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=112240
# Break page: 185
# Elapsed time: 0:00:30.328500
# [171]
# Crawling Company Name: 에스엔텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=160600
# Break page: 97
# Elapsed time: 0:00:33.546492
# [172]
# Crawling Company Name: 에스코넥
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=096630
# Break page: 283
# Elapsed time: 0:00:45.403952
# [173]
# Crawling Company Name: 에스티오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=098660
# Break page: 250
# Elapsed time: 0:00:45.597568
# [174]
# Crawling Company Name: 에이치엔티
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=176440
# Break page: 61
# Elapsed time: 0:00:06.995950
# [175]
# Crawling Company Name: 에이티넘인베스트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=021080
# Break page: 519
# Elapsed time: 0:01:22.047153
# [176]
# Crawling Company Name: 에이피티씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=089970
# Break page: 19
# Elapsed time: 0:00:02.170315
# [177]
# Crawling Company Name: 에코마이스터
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=064510
# Break page: 30
# Elapsed time: 0:00:03.160913
# [178]
# Crawling Company Name: 에코마케팅
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=230360
# Break page: 69
# Elapsed time: 0:00:09.365820
# [179]
# Crawling Company Name: 에프에스티
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036810
# Break page: 475
# Elapsed time: 0:01:04.281838
# [180]
# Crawling Company Name: 엑셈
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=205100
# Break page: 112
# Elapsed time: 0:00:24.292844
# [181]
# Crawling Company Name: 엘비세미콘
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=061970
# Break page: 205
# Elapsed time: 0:00:33.559193
# [182]
# Crawling Company Name: 엘아이에스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=138690
# Break page: 197
# Elapsed time: 0:00:25.204848
# [183]
# Crawling Company Name: 연이정보통신
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=090740
# Break page: 289
# Elapsed time: 0:00:35.522690
# [184]
# Crawling Company Name: 영신금속
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007530
# Break page: 519
# Elapsed time: 0:01:11.535228
# [185]
# Crawling Company Name: 오공
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=045060
# Break page: 464
# Elapsed time: 0:01:00.101470
# [186]
# Crawling Company Name: 오스템임플란트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=048260
# Break page: 304
# Elapsed time: 0:00:37.728303
# [187]
# Crawling Company Name: 오이솔루션
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=138080
# Break page: 129
# Elapsed time: 0:00:15.333474
# [188]
# Crawling Company Name: 오픈베이스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=049480
# Break page: 454
# Elapsed time: 0:00:57.578022
# [189]
# Crawling Company Name: 옵티팜
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=153710
# Break page: 15
# Elapsed time: 0:00:01.756643
# [190]
# Crawling Company Name: 와이지-원
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=019210
# Break page: 519
# Elapsed time: 0:01:24.067484
# [191]
# Crawling Company Name: 원익큐브
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=014190
# Break page: 519
# Elapsed time: 0:01:08.419662
# [192]
# Crawling Company Name: 원풍물산
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008290
# Break page: 519
# Elapsed time: 0:01:10.866541
# [193]
# Crawling Company Name: 웨이브일렉트로
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=095270
# Break page: 290
# Elapsed time: 0:00:46.097833
# [194]
# Crawling Company Name: 웰크론
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=065950
# Break page: 392
# Elapsed time: 0:00:57.512597
# [195]
# Crawling Company Name: 위지트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036090
# Break page: 477
# Elapsed time: 0:01:25.112376
# [196]
# Crawling Company Name: 유바이오로직스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=206650
# Break page: 57
# Elapsed time: 0:00:12.663669
# [197]
# Crawling Company Name: 육일씨엔에쓰
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=191410
# Break page: 84
# Elapsed time: 0:00:09.351925
# [198]
# Crawling Company Name: 이노인스트루먼트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=215790
# Break page: 100
# Elapsed time: 0:00:13.183760
# [199]
# Crawling Company Name: 이상네트웍스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=080010
# Break page: 338
# Elapsed time: 0:00:46.896639
# [200]
# Crawling Company Name: 이스트소프트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=047560
# Break page: 270
# Elapsed time: 0:00:52.394117
# [201]
# Crawling Company Name: 이엔에프테크놀로지
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=102710
# Break page: 248
# Elapsed time: 0:00:30.885804
# [202]
# Crawling Company Name: 잉크테크
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=049550
# Break page: 427
# Elapsed time: 0:01:06.966443
# [203]
# Crawling Company Name: 제넨바이오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=072520
# Break page: 361
# Elapsed time: 0:00:44.298956
# [204]
# Crawling Company Name: 제우스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=079370
# Break page: 330
# Elapsed time: 0:00:47.297148
# [205]
# Crawling Company Name: 제이엔케이히터
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=126880
# Break page: 205
# Elapsed time: 0:00:33.919293
# [206]
# Crawling Company Name: 제이엠티
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=094970
# Break page: 288
# Elapsed time: 0:00:55.065676
# [207]
# Crawling Company Name: 제주반도체
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=080220
# Break page: 355
# Elapsed time: 0:00:55.695670
# [208]
# Crawling Company Name: 조아제약
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=034940
# Break page: 486
# Elapsed time: 0:01:11.867310
# [209]
# Crawling Company Name: 주성엔지니어링
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036930
# Break page: 476
# Elapsed time: 0:01:02.634659
# [210]
# Crawling Company Name: 지엔코
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=065060
# Break page: 421
# Elapsed time: 0:01:03.101001
# [211]
# Crawling Company Name: 지투하이소닉
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=106080
# Break page: 230
# Elapsed time: 0:00:31.014276
# [212]
# Crawling Company Name: 진매트릭스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=109820
# Break page: 236
# Elapsed time: 0:00:28.655334
# [213]
# Crawling Company Name: 창해에탄올
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=004650
# Break page: 119
# Elapsed time: 0:00:20.642337
# [214]
# Crawling Company Name: 케이피엠테크
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=042040
# Break page: 406
# Elapsed time: 0:00:52.543087
# [215]
# Crawling Company Name: 케이피티유
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=054410
# Break page: 423
# Elapsed time: 0:01:24.927265
# [216]
# Crawling Company Name: 켐트로스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=220260
# Break page: 94
# Elapsed time: 0:00:13.019118
# [217]
# Crawling Company Name: 코센
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=009730
# Break page: 519
# Elapsed time: 0:01:25.685590
# [218]
# Crawling Company Name: 코스온
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=069110
# Break page: 387
# Elapsed time: 0:01:14.641255
# [219]
# Crawling Company Name: 코아스템
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=166480
# Break page: 97
# Elapsed time: 0:00:11.683373
# [220]
# Crawling Company Name: 코이즈
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=121850
# Break page: 164
# Elapsed time: 0:00:19.930279
# [221]
# Crawling Company Name: 코프라
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=126600
# Break page: 211
# Elapsed time: 0:00:30.189102
# [222]
# Crawling Company Name: 토탈소프트
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=045340
# Break page: 417
# Elapsed time: 0:00:57.164167
# [223]
# Crawling Company Name: 톱텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=108230
# Break page: 240
# Elapsed time: 0:00:33.863407
# [224]
# Crawling Company Name: 트루윈
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=105550
# Break page: 120
# Elapsed time: 0:00:14.715396
# [225]
# Crawling Company Name: 특수건설
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=026150
# Break page: 519
# Elapsed time: 0:01:23.270076
# [226]
# Crawling Company Name: 파세코
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=037070
# Break page: 476
# Elapsed time: 0:01:04.978344
# [227]
# Crawling Company Name: 파수닷컴
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=150900
# Break page: 138
# Elapsed time: 0:00:16.599764
# [228]
# Crawling Company Name: 판타지오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=032800
# Break page: 519
# Elapsed time: 0:01:14.662484
# [229]
# Crawling Company Name: 푸드웰
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005670
# Break page: 519
# Elapsed time: 0:01:17.001076
# [230]
# Crawling Company Name: 푸른저축은행
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007330
# Break page: 519
# Elapsed time: 0:01:20.478918
# [231]
# Crawling Company Name: 퓨전데이타
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=195440
# Break page: 60
# Elapsed time: 0:00:06.837986
# [232]
# Crawling Company Name: 프로스테믹스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=203690
# Break page: 115
# Elapsed time: 0:00:14.048056
# [233]
# Crawling Company Name: 피에스엠씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=024850
# Break page: 454
# Elapsed time: 0:01:00.380757
# [234]
# Crawling Company Name: 피에스케이
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=319660
# Break page: 2
# Elapsed time: 0:00:00.277272
# [235]
# Crawling Company Name: 하나금융10호스팩
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=270520
# Break page: 43
# Elapsed time: 0:00:04.659610
# [236]
# Crawling Company Name: 하이셈
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=200470
# Break page: 109
# Elapsed time: 0:00:12.456548
# [237]
# Crawling Company Name: 한국맥널티
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=222980
# Break page: 84
# Elapsed time: 0:00:09.717301
# [238]
# Crawling Company Name: 한국전자금융
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=063570
# Break page: 318
# Elapsed time: 0:00:42.713605
# [239]
# Crawling Company Name: 한국전자인증
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=041460
# Break page: 210
# Elapsed time: 0:00:30.331988
# [240]
# Crawling Company Name: 한류AI센터
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=222810
# Break page: 93
# Elapsed time: 0:00:10.800156
# [241]
# Crawling Company Name: 한양디지텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=078350
# Break page: 373
# Elapsed time: 0:00:51.706408
# [242]
# Crawling Company Name: 한일화학
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007770
# Break page: 519
# Elapsed time: 0:01:09.316186
# [243]
# Crawling Company Name: 한컴MDS
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=086960
# Break page: 313
# Elapsed time: 0:00:49.346111
# [244]
# Crawling Company Name: 한화에이스스팩4호
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=279410
# Break page: 37
# Elapsed time: 0:00:04.427517
# [245]
# Crawling Company Name: 해성옵틱스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=076610
# Break page: 137
# Elapsed time: 0:00:16.223015
# [246]
# Crawling Company Name: 헝셩그룹
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=900270
# Break page: 68
# Elapsed time: 0:00:08.228938
# [247]
# Crawling Company Name: 화성밸브
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=039610
# Break page: 471
# Elapsed time: 0:01:14.545175
# [248]
# Crawling Company Name: 화이브라더스코리아
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=204630
# Break page: 109
# Elapsed time: 0:00:12.797532
# [249]
# Crawling Company Name: 휴메딕스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=200670
# Break page: 109
# Elapsed time: 0:00:12.008890
# [250]
# Crawling Company Name: LPK로보틱스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=183350
# Break page: 138
# Elapsed time: 0:00:15.754284
# [251]
# Crawling Company Name: 나눔테크
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=244880
# Break page: 74
# Elapsed time: 0:00:13.686459
# [252]
# Crawling Company Name: 두원석재
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=270020
# Break page: 42
# Elapsed time: 0:00:05.554984
# [253]
# Crawling Company Name: 래몽래인
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=200350
# Break page: 109
# Elapsed time: 0:00:20.652273
# [254]
# Crawling Company Name: 리메드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=302550
# Break page: 20
# Elapsed time: 0:00:02.429432
# [255]
# Crawling Company Name: 시그넷이브이
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=260870
# Break page: 43
# Elapsed time: 0:00:10.331943
# [256]
# Crawling Company Name: 에듀파트너
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=208890
# Break page: 109
# Elapsed time: 0:00:17.925510
# [257]
# Crawling Company Name: 에스엘에스바이오
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=246250
# Break page: 72
# Elapsed time: 0:00:08.284723
# [258]
# Crawling Company Name: 에이원알폼
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=234070
# Break page: 84
# Elapsed time: 0:00:10.714176
# [259]
# Crawling Company Name: 에프앤가이드
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=064850
# Break page: 145
# Elapsed time: 0:00:19.377466
# [260]
# Crawling Company Name: 유비온
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=084440
# Break page: 132
# Elapsed time: 0:00:20.425273
# [261]
# Crawling Company Name: 이노벡스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=279060
# Break page: 4
# Elapsed time: 0:00:00.359724
# [262]
# Crawling Company Name: 인카금융서비스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=211050
# Break page: 87
# Elapsed time: 0:00:09.978446
# [263]
# Crawling Company Name: 전우정밀
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=120780
# Break page: 60
# Elapsed time: 0:00:08.157657
# [264]
# Crawling Company Name: 지놈앤컴퍼니
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=314130
# Break page: 11
# Elapsed time: 0:00:01.094360
# [265]
# Crawling Company Name: 테크트랜스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=258050
# Break page: 22
# Elapsed time: 0:00:02.553519
# [266]
# Crawling Company Name: 티케이씨
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=191600
# Break page: 69
# Elapsed time: 0:00:12.602364
# [267]
# Crawling Company Name: 파워풀엑스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=266870
# Break page: 51
# Elapsed time: 0:00:05.595223
# [268]
# Crawling Company Name: BGF
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=027410
# Break page: 124
# Elapsed time: 0:00:14.344732
# [269]
# Crawling Company Name: BNK금융지주
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=138930
# Break page: 201
# Elapsed time: 0:00:23.172550
# [270]
# Crawling Company Name: CS홀딩스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=000590
# Break page: 577
# Elapsed time: 0:01:24.131880
# [271]
# Crawling Company Name: GKL
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=114090
# Break page: 235
# Elapsed time: 0:00:36.163203
# [272]
# Crawling Company Name: GS건설
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=006360
# Break page: 577
# Elapsed time: 0:01:23.643440
# [273]
# Crawling Company Name: KB금융
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=105560
# Break page: 263
# Elapsed time: 0:00:31.254521
# [274]
# Crawling Company Name: LG디스플레이
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=034220
# Break page: 368
# Elapsed time: 0:01:03.683598
# [275]
# Crawling Company Name: S&T모티브
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=064960
# Break page: 426
# Elapsed time: 0:01:04.242459
# [276]
# Crawling Company Name: SG충방
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001380
# Break page: 577
# Elapsed time: 0:01:25.014731
# [277]
# Crawling Company Name: SK
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=034730
# Break page: 236
# Elapsed time: 0:00:27.887220
# [278]
# Crawling Company Name: SKC
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=011790
# Break page: 543
# Elapsed time: 0:01:22.061743
# [279]
# Crawling Company Name: 금강공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=014280
# Break page: 574
# Elapsed time: 0:01:19.823232
# [280]
# Crawling Company Name: 금호산업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=002990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-0a68de15d343> in <module>
#       3 for idx, company_name in enumerate(company_info['name']):
#       4     print('[%i]' %idx)
# ----> 5     stock_data = get_stock_data(company_name=company_name)
#       6     all_data = pd.concat([all_data, stock_data])
#
# <ipython-input-18-7f8312481a16> in get_stock_data(company_name, by_year, recent_n_data)
#      31         #     print(page)
#      32         pg_url = '{url}&page={page}'.format(url=url, page=page)
# ---> 33         d = pd.read_html(pg_url, header=0)[0]
#      34         d = d.dropna()
#      35
#
# /data1/virtualenv/brainwave_eeg/venv/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#     985                   decimal=decimal, converters=converters, na_values=na_values,
#     986                   keep_default_na=keep_default_na,
# --> 987                   displayed_only=displayed_only)
#
# /data1/virtualenv/brainwave_eeg/venv/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     795
#     796         try:
# --> 797             tables = p.parse_tables()
#     798         except Exception as caught:
#     799             # if `io` is an io-like object, check if it's seekable
#
# /data1/virtualenv/brainwave_eeg/venv/lib/python3.6/site-packages/pandas/io/html.py in parse_tables(self)
#     211
#     212     def parse_tables(self):
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._build_table(table) for table in tables)
#     215
#
# /data1/virtualenv/brainwave_eeg/venv/lib/python3.6/site-packages/pandas/io/html.py in _build_doc(self)
#     614             if _is_url(self.io):
#     615                 with urlopen(self.io) as f:
# --> 616                     r = parse(f, parser=parser)
#     617             else:
#     618                 # try to parse the input in the simplest way
#
# /data1/virtualenv/brainwave_eeg/venv/lib/python3.6/site-packages/lxml/html/__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseFilelikeDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/parser.pxi in lxml.etree._FileReaderContext.copyToBuffer()
#
# ~/anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     436         return self.fp is None
#     437
# --> 438     def read(self, amt=None):
#     439         if self.fp is None:
#     440             return b""
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. 수집된 모든 데이터를 pandas로 저장합니다.

# %%
all_data.to_csv('/data1/stock_data/2019_05_14_stock_data.csv')
print('Data saved!!')
# Out:
# Data saved!!

# %% [markdown]
# # Extras: #1. 주가 데이터의 여러 feature를 더하는함수입니다.

# %%
class Features:

    @staticmethod
    def fnMACD(m_Df, m_NumFast=12, m_NumSlow=26, m_NumSignal=9):
        m_Df['EMAFast'] = m_Df['final_price'].ewm(span=m_NumFast, min_periods=m_NumFast - 1).mean()
        m_Df['EMASlow'] = m_Df['final_price'].ewm(span=m_NumSlow, min_periods=m_NumSlow - 1).mean()
        m_Df['MACD'] = m_Df['EMAFast'] - m_Df['EMASlow']
        m_Df['MACDSignal'] = m_Df['MACD'].ewm(span=m_NumSignal, min_periods=m_NumSignal - 1).mean()
        m_Df['MACDDiff'] = m_Df['MACD'] - m_Df['MACDSignal']
        return m_Df

    @staticmethod
    def fnBolingerBand(m_DF, n=20, k=2):
        m_DF['20d_ma'] = pd.rolling_mean(m_DF['final_price'], window=n)
        m_DF['Bol_upper'] = pd.rolling_mean(m_DF['final_price'], window=n) + k * pd.rolling_std(m_DF['final_price'], n,
                                                                                                min_periods=n)
        m_DF['Bol_lower'] = pd.rolling_mean(m_DF['final_price'], window=n) - k * pd.rolling_std(m_DF['final_price'], n,
                                                                                                min_periods=n)

        return m_DF

    @staticmethod
    def fnRSI(m_Df, m_N=14):
        U = np.where(m_Df['final_price'].diff(1) > 0, m_Df['final_price'].diff(1), 0)
        D = np.where(m_Df['final_price'].diff(1) < 0, m_Df['final_price'].diff(1) * (-1), 0)

        AU = pd.DataFrame(U).rolling(window=m_N, min_periods=m_N).mean()
        AD = pd.DataFrame(D).rolling(window=m_N, min_periods=m_N).mean()
        RSI = AU.div(AD + AU) * 100

        m_Df['RSI'] = RSI
        return m_Df

    @staticmethod
    def fnStoch(m_Df, n=14):  # price: 종가(시간 오름차순), n: 기간
        sz = len(m_Df['final_price'])

        tempSto_K = []
        for i in range(sz):
            if i >= n - 1:
                tempUp = m_Df['final_price'][i] - min(m_Df['lowest_price'][i - n + 1:i + 1])
                tempDown = max(m_Df['highest_price'][i - n + 1:i + 1]) - min(m_Df['lowest_price'][i - n + 1:i + 1])
                tempSto_K.append(tempUp / tempDown)
            else:
                tempSto_K.append(0)  # n보다 작은 초기값은 0 설정
        m_Df['Sto_K'] = pd.Series(tempSto_K, index=m_Df.index)

        m_Df['Sto_D'] = pd.Series(pd.rolling_mean(m_Df['Sto_K'], 3))
        m_Df['Sto_SlowD'] = pd.Series(pd.rolling_mean(m_Df['Sto_D'], 3))

        return m_Df

    @staticmethod
    def fnMA(m_Df, m_N=list(), m_ColumnName='final_price'):
        all_MA = list()
        if m_ColumnName in m_Df.columns:
            for num in m_N:
                MA = pd.Series.rolling(m_Df[m_ColumnName], window=num, center=False).mean()
                m_Df['MA' + str(num)] = MA

                all_MA.append(MA)

            for i in range(len(all_MA)):
                if i + 1 == len(all_MA):
                    break

                for i2 in range(i + 1, len(all_MA)):
                    m_Df['SignalMA' + str(m_N[i]) + '_' + str(m_N[i2])] = all_MA[i] - all_MA[i2]

        else:
            raise ("You didn't input a Column Name")
        return m_Df

    @staticmethod
    def change_prior_to(m_Df):

        m_Df['compare_to_prior'] = m_Df['final_price'].diff(1)
        m_Df['percent'] = (m_Df['final_price'] * 100 / (m_Df['final_price'] - m_Df['compare_to_prior']) - 100).round(2)

        return m_Df

# %% [markdown]
# # Extras: 일련의 과정을 class화 합니다.

# %%
class StockCollector:
    def __init__(self):
        self.company_info = self._retrieve_company_info()
        
    def _retrieve_company_info(self):
        code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
        # 종목코드가 6자리이기 때문에 6자리를 맞춰주기 위해 설정해줌
        code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)
        # 우리가 필요한 것은 회사명과 종목코드이기 때문에 필요없는 column들은 제외해준다.
        code_df = code_df[['회사명', '종목코드']]  # 한글로된 컬럼명을 영어로 바꿔준다.
        company_info = code_df.rename(columns={'회사명': 'name', '종목코드': 'code'})
        return company_info
    
    def get_stock_data_by_company(self, company_name, by_year=list(), recent_n_data=list()):
        t = datetime.now()
        print('Crawling Company Name:', company_name)

        # 1. 회사 종목코드와 데이터를 수집하기 위한 대상 url을 생성합닏.
        code = self.company_info.query("name=='{}'".format(company_name))['code'].to_string(index=False)
        url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
        print("요청 URL = {}".format(url))

        # 2. (option) 지정된 year 또는 타겟 날짜로부터 가장 최근 n일의 데이터를 수집하고자 할 때 지정하기 위한 로직입니다.
        yrs = ""
        min_year = -1
        target_date = -1
        num_seq = -1

        if len(recent_n_data) == 2:
            target_date = str(recent_n_data[0])
            target_date = target_date[:4] + '.' + target_date[4:6] + '.' + target_date[6:8]  # yyyy.mm.dd
            num_seq = recent_n_data[1]

        if len(by_year) != 0 and target_date == -1:
            yrs = "|".join(str(yr) for yr in by_year)
            min_year = sorted(by_year)[0]
            print('Collecting years... ', by_year)
            # print('Mininum Year: %i' % min_year)

        # 3. UI에 Display된 페이지 데이터를 수집하기 때문에 max page를 정해놓고 시도합니다.
        max_page = 1000
        df = pd.DataFrame()

        for page in range(1, max_page):
            pg_url = '{url}&page={page}'.format(url=url, page=page)
            d = pd.read_html(pg_url, header=0)[0]
            d = d.dropna()

            # 3-1. 마지막 페이지 수집시, 이전 페이지의 중복된 날짜도 함께 수집되었는지 확인하고 프로세스를 멈춥니다.
            if df.shape[0] != 0 and len(d['날짜']) > 1 and d['날짜'][1] in df['날짜'].tolist():
                # Max page reached
                print('Break page:', page)
                break

            # 3-2. 타겟 날짜에 대한 데이터만 수집할 때에만 해당됩니다.
            if target_date != -1:
                if df.shape[0] == 0:
                    d = d[d['날짜'].str.contains(target_date)]
                    if d.shape[0] == 0:
                        continue

                df = df.append(d)

                if df.shape[0] >= num_seq:
                    df = df.head(num_seq)
                    break

            # 3-3. 타겟 year만 수집할 때에만 해당됩니다. 타겟 year 이전 해의 데이터가 수집되었다면 프로세스를 멈춥니다.
            if min_year != -1 and target_date == -1 and min_year > int(d['날짜'][d.shape[0] - 1][:4]):
                print('Found minimum year, break page:', page)
                break

            df = df.append(d, ignore_index=True)

        # 4. 수집된 데이터를 가볍게 가공합니다.
        df['name'] = pd.Series([company_name] * len(df['날짜']), index=df.index)
        df = df.rename(columns={'날짜': 'date', '종가': 'final_price', '전일비': 'compare_to_prior', '시가': 'start_price',
                                '고가': 'highest_price', '저가': 'lowest_price', '거래량': 'num_of_traded'})

        # 5. 수집된 데이터 중 타겟 year에 해당하는 데이터만 재정리 합니다.
        if min_year != -1:
            df = df[df['date'].str.contains(yrs)]

        t = datetime.now() - t
        print('Elapsed time:', t)

        return df
    
    def start_data_collection(self, save_path, autosave=True, save_by_company=True):
        all_data = pd.DataFrame()
        collect_start_time = datetime.now()
        today_date = datetime.today().strftime('%Y%m%d')
        save_full_path = join(save_path, today_date + '_stock_data.csv')
        for idx, company_name in enumerate(company_info['name']):
            if idx < 1151 or idx == 1176:
                continue
            print('[%i]' %idx)
            stock_data = self.get_stock_data_by_company(company_name=company_name)
            all_data = pd.concat([all_data, stock_data])
            
            if autosave and idx % 50 == 0:
                all_data.to_csv(save_full_path)
                
        all_data.to_csv(join(save_path, today_date + '_stock_data.csv'))
        print('Crawling data finished. Total elapsed time:', datetime.now() - collect_start_time)
        if save_by_company:
            self.split_data_by_company(input_path=save_full_path, output_path=save_path)
        
    def split_data_by_company(self, input_path, output_path):

        df = pd.read_csv(input_path, index_col=0)

        if not exists(output_path):
            makedirs(output_path)

        for idx, company_name in enumerate(df.name.unique()):
            print(idx, company_name)
            a = df.loc[df['name'] == company_name]
            a = a.loc[:, a.columns != 'name']
            np.save(join(output_path, company_name), a)

        print('All data saved by company name. Length of company:', len(df.name.unique()))

    def add_features(self, input_path=None, output_path=None, df=None):

        if df is None:
            df = pd.read_csv(input_path)

        df_new = pd.DataFrame()
        for idx, name in enumerate(df.name.unique()):
            print(idx, name)
            try:
                df_temp = df[df['name'] == name].sort_values(by=['date']).reset_index(drop=True)
                df_temp = Features.fnMACD(df_temp)
                df_temp = Features.fnBolingerBand(df_temp)
                df_temp = Features.fnRSI(df_temp)
                df_temp = Features.fnStoch(df_temp)
                df_temp = Features.change_prior_to(df_temp)
                df_temp = Features.fnMA(df_temp, m_N=[5, 20, 60, 120, 240])
            except Exception as e:
                print('Error occurred while adding features at index %i %s' % (idx, name))
                print(e)
                continue
            df_new = pd.concat([df_new, df_temp])

        df = df_new.reset_index(drop=True)

        if output_path is not None:
            if not exists(dirname(output_path)):
                makedirs(dirname(output_path))
            df.to_csv(output_path)

        return df

# %%
stock_collector = StockCollector()
stock_collector.start_data_collection(save_path='/data1/stock_data', autosave=True, save_by_company=False)
# Out:
# [1151]
# Crawling Company Name: 동원F&B
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=049770
# Break page: 458
# Elapsed time: 0:01:16.048271
# [1152]
# Crawling Company Name: 두산밥캣
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=241560
# Break page: 62
# Elapsed time: 0:00:12.028806
# [1153]
# Crawling Company Name: 두산중공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=034020
# Break page: 460
# Elapsed time: 0:01:11.628296
# [1154]
# Crawling Company Name: 드림텍
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=192650
# Break page: 6
# Elapsed time: 0:00:00.651931
# [1155]
# Crawling Company Name: 디아이동일
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001530
# Break page: 577
# Elapsed time: 0:01:41.036808
# [1156]
# Crawling Company Name: 롯데제과
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=280360
# Break page: 39
# Elapsed time: 0:00:03.853182
# [1157]
# Crawling Company Name: 만호제강
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001080
# Break page: 577
# Elapsed time: 0:01:20.057611
# [1158]
# Crawling Company Name: 모나미
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=005360
# Break page: 577
# Elapsed time: 0:01:17.039965
# [1159]
# Crawling Company Name: 문배철강
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=008420
# Break page: 577
# Elapsed time: 0:01:04.952133
# [1160]
# Crawling Company Name: 미래에셋생명
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=085620
# Break page: 96
# Elapsed time: 0:00:08.013775
# [1161]
# Crawling Company Name: 미창석유공업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003650
# Break page: 577
# Elapsed time: 0:00:59.798946
# [1162]
# Crawling Company Name: 백광산업
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=001340
# Break page: 577
# Elapsed time: 0:00:59.701715
# [1163]
# Crawling Company Name: 벽산
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=007210
# Break page: 577
# Elapsed time: 0:01:12.444293
# [1164]
# Crawling Company Name: 부광약품
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=003000
# Break page: 577
# Elapsed time: 0:01:21.744637
# [1165]
# Crawling Company Name: 부산도시가스
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=015350
